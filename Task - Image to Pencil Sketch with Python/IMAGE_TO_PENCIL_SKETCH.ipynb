# %% [markdown]
# ## LetsGrowMore
# ## TASK : Image to Pencil Sketch with Python
# ## By : Vikram Borana P

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from PIL import Image
import cv2

image=cv2.imread("/content/whale.jpeg")
image = cv2.resize(image,(500,300))
img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(img_rgb)

# %% [markdown]
# ### Converting  Image into Gray Scale

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.figure(figsize=(10, 10))
plt.imshow(gray_image)

# %% [markdown]
# ### Inverting the image

# %%
inverted_image = cv2.bitwise_not(gray_image)
plt.figure(figsize=(10, 10))
plt.imshow(inverted_image)

# %% [markdown]
# ### Smoothing the image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
plt.figure(figsize=(10, 10))
plt.imshow(img_smoothing)

# %%
def pencilsketch(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# ### Inverting the Image to get the Pencil Sketch

# %%
pencil_sketch = pencilsketch(gray_image, img_smoothing)
plt.figure(figsize=(10, 10))
plt.imshow(pencil_sketch)

# %% [markdown]
# ### Comparing the Original Image with Pencil Sketch

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x7F9BF135A0D0>
# <PIL.Image.Image image mode=L size=500x300 at 0x7F9BF13E7CD0>
